# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_parquet("C:/Users/qkrtl/10th/00_Project/04_final/02_parquet_file/04_temp_parquet_files/analysis_output/erangel_features.parquet")

# %%
df1.T
# Out:
#                                                            0       \
# matchId                      000c936c-b00b-47f0-9e1b-493d589f99bd
# accountId                account.0038d4bb0dcc4a05b68d39589da0236e
# rotation_timing_score                                         NaN
# vehicle_use_ratio                                             0.0
# bluezone_exposure_ratio                                       0.0
# safezone_proximity_mean                                2783.81673
# safezone_edge_ratio                                      0.004783
# altitude_variance                                      125.964431
# survival_time                                               130.0
# total_movement                                       12359.044434
# drop_distance_from_path                               1379.728838
# drop_x                                                 608259.625
# drop_y                                                 598414.375
# ...

# %%
df2 = pd.read_parquet("C:/Users/qkrtl/10th/00_Project/04_final/02_parquet_file/04_temp_parquet_files/analysis_output/erangel_clustered.parquet")
df2.T
# Out:
#                                                            0       \
# matchId                      000c936c-b00b-47f0-9e1b-493d589f99bd
# accountId                account.0038d4bb0dcc4a05b68d39589da0236e
# rotation_timing_score                                     0.54413
# vehicle_use_ratio                                             0.0
# bluezone_exposure_ratio                                       0.0
# safezone_proximity_mean                                2783.81673
# safezone_edge_ratio                                      0.004783
# altitude_variance                                      125.964431
# survival_time                                               130.0
# total_movement                                       12359.044434
# drop_distance_from_path                               1379.728838
# drop_x                                                 608259.625
# drop_y                                                 598414.375
# ...
