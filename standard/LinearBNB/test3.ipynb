# %% [markdown]
# main subject : 신규 호스트가 어떤 가격에 숙소를 올려야 하는가?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("C:/msys64/home/for/10th/standard/LinearBNB/2025_Airbnb_NYC_listings.csv")
df.T
# Out:
#                                                                                           0      \
# Unnamed: 0                                                                                    0
# id                                                                                        36121
# source                                                                              city scrape
# name                                                         Lg Rm in Historic Prospect Heights
# description                                   Cozy space share in the heart of a great neigh...
# ...                                                                                         ...
# calculated_host_listings_count                                                                1
# calculated_host_listings_count_entire_homes                                                   0
# calculated_host_listings_count_private_rooms                                                  1
# ...

# %%
df.isnull().sum()[['number_of_reviews', 'reviews_per_month', 'review_scores_rating',
                   'review_scores_cleanliness', 'review_scores_communication', 'first_review', 'last_review']]

# number_of_reviews                 0
# reviews_per_month              6798
# review_scores_rating           6798
# review_scores_cleanliness      6798
# review_scores_communication    6798
# first_review                   6798
# last_review                    6798
# Out:
# number_of_reviews                 0
# reviews_per_month              6798
# review_scores_rating           6798
# review_scores_cleanliness      6798
# review_scores_communication    6798
# first_review                   6798
# last_review                    6798
# dtype: int64

# %%
# Out:
# C:\Users\for\AppData\Local\Temp\ipykernel_17640\2353513067.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   df1 = df.copy().dropna([['number_of_reviews', 'reviews_per_month', 'review_scores_rating',
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df1 = df.copy().dropna([['number_of_reviews', 'reviews_per_month', 'review_scores_rating',
#       2                    'review_scores_cleanliness', 'review_scores_communication', 'first_review', 'last_review']])
#
# File c:\Users\for\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...
